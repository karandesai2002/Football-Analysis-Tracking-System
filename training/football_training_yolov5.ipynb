# %%
# !pip install ultralytics
# !pip install roboflow
# Out:
# Requirement already satisfied: ultralytics in /Applications/anaconda3/envs/football-analysis/lib/python3.10/site-packages (8.4.21)
# Requirement already satisfied: numpy>=1.23.0 in /Applications/anaconda3/envs/football-analysis/lib/python3.10/site-packages (from ultralytics) (2.2.6)
# Requirement already satisfied: matplotlib>=3.3.0 in /Applications/anaconda3/envs/football-analysis/lib/python3.10/site-packages (from ultralytics) (3.10.8)
# Requirement already satisfied: opencv-python>=4.6.0 in /Applications/anaconda3/envs/football-analysis/lib/python3.10/site-packages (from ultralytics) (4.13.0.92)
# Requirement already satisfied: pillow>=7.1.2 in /Applications/anaconda3/envs/football-analysis/lib/python3.10/site-packages (from ultralytics) (12.1.1)
# Requirement already satisfied: pyyaml>=5.3.1 in /Applications/anaconda3/envs/football-analysis/lib/python3.10/site-packages (from ultralytics) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in /Applications/anaconda3/envs/football-analysis/lib/python3.10/site-packages (from ultralytics) (2.32.5)
# Requirement already satisfied: scipy>=1.4.1 in /Applications/anaconda3/envs/football-analysis/lib/python3.10/site-packages (from ultralytics) (1.15.3)
# Requirement already satisfied: torch>=1.8.0 in /Applications/anaconda3/envs/football-analysis/lib/python3.10/site-packages (from ultralytics) (2.10.0)
# Requirement already satisfied: torchvision>=0.9.0 in /Applications/anaconda3/envs/football-analysis/lib/python3.10/site-packages (from ultralytics) (0.25.0)
# Requirement already satisfied: psutil>=5.8.0 in /Applications/anaconda3/envs/football-analysis/lib/python3.10/site-packages (from ultralytics) (7.0.0)
# Requirement already satisfied: polars>=0.20.0 in /Applications/anaconda3/envs/football-analysis/lib/python3.10/site-packages (from ultralytics) (1.38.1)
# Requirement already satisfied: ultralytics-thop>=2.0.18 in /Applications/anaconda3/envs/football-analysis/lib/python3.10/site-packages (from ultralytics) (2.0.18)
# Requirement already satisfied: contourpy>=1.0.1 in /Applications/anaconda3/envs/football-analysis/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /Applications/anaconda3/envs/football-analysis/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Applications/anaconda3/envs/football-analysis/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Applications/anaconda3/envs/football-analysis/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /Applications/anaconda3/envs/football-analysis/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (25.0)
# Requirement already satisfied: pyparsing>=3 in /Applications/anaconda3/envs/football-analysis/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Applications/anaconda3/envs/football-analysis/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: polars-runtime-32==1.38.1 in /Applications/anaconda3/envs/football-analysis/lib/python3.10/site-packages (from polars>=0.20.0->ultralytics) (1.38.1)
# Requirement already satisfied: six>=1.5 in /Applications/anaconda3/envs/football-analysis/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Applications/anaconda3/envs/football-analysis/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /Applications/anaconda3/envs/football-analysis/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Applications/anaconda3/envs/football-analysis/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Applications/anaconda3/envs/football-analysis/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics) (2026.2.25)
# Requirement already satisfied: filelock in /Applications/anaconda3/envs/football-analysis/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (3.25.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /Applications/anaconda3/envs/football-analysis/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in /Applications/anaconda3/envs/football-analysis/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /Applications/anaconda3/envs/football-analysis/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (3.4.2)
# Requirement already satisfied: jinja2 in /Applications/anaconda3/envs/football-analysis/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /Applications/anaconda3/envs/football-analysis/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (2026.2.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Applications/anaconda3/envs/football-analysis/lib/python3.10/site-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Applications/anaconda3/envs/football-analysis/lib/python3.10/site-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.3)
# Collecting roboflow
#   Downloading roboflow-1.2.16-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: certifi in /Applications/anaconda3/envs/football-analysis/lib/python3.10/site-packages (from roboflow) (2026.2.25)
# Collecting idna==3.7 (from roboflow)
#   Downloading idna-3.7-py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: cycler in /Applications/anaconda3/envs/football-analysis/lib/python3.10/site-packages (from roboflow) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Applications/anaconda3/envs/football-analysis/lib/python3.10/site-packages (from roboflow) (1.4.9)
# Requirement already satisfied: matplotlib in /Applications/anaconda3/envs/football-analysis/lib/python3.10/site-packages (from roboflow) (3.10.8)
# Requirement already satisfied: numpy>=1.18.5 in /Applications/anaconda3/envs/football-analysis/lib/python3.10/site-packages (from roboflow) (2.2.6)
# Collecting opencv-python-headless==4.10.0.84 (from roboflow)
#   Using cached opencv_python_headless-4.10.0.84-cp37-abi3-macosx_11_0_arm64.whl.metadata (20 kB)
# Requirement already satisfied: Pillow>=7.1.2 in /Applications/anaconda3/envs/football-analysis/lib/python3.10/site-packages (from roboflow) (12.1.1)
# Collecting pillow-avif-plugin<2 (from roboflow)
#   Downloading pillow_avif_plugin-1.5.5-cp310-cp310-macosx_11_0_arm64.whl.metadata (2.2 kB)
# Requirement already satisfied: python-dateutil in /Applications/anaconda3/envs/football-analysis/lib/python3.10/site-packages (from roboflow) (2.9.0.post0)
# Collecting python-dotenv (from roboflow)
#   Downloading python_dotenv-1.2.2-py3-none-any.whl.metadata (27 kB)
# Requirement already satisfied: requests in /Applications/anaconda3/envs/football-analysis/lib/python3.10/site-packages (from roboflow) (2.32.5)
# Requirement already satisfied: six in /Applications/anaconda3/envs/football-analysis/lib/python3.10/site-packages (from roboflow) (1.17.0)
# Requirement already satisfied: urllib3>=1.26.6 in /Applications/anaconda3/envs/football-analysis/lib/python3.10/site-packages (from roboflow) (2.6.3)
# Collecting tqdm>=4.41.0 (from roboflow)
#   Downloading tqdm-4.67.3-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: PyYAML>=5.3.1 in /Applications/anaconda3/envs/football-analysis/lib/python3.10/site-packages (from roboflow) (6.0.3)
# Collecting requests-toolbelt (from roboflow)
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Collecting filetype (from roboflow)
#   Using cached filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting pi-heif<2 (from roboflow)
#   Downloading pi_heif-1.3.0-cp310-cp310-macosx_11_0_arm64.whl.metadata (6.3 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /Applications/anaconda3/envs/football-analysis/lib/python3.10/site-packages (from matplotlib->roboflow) (1.3.2)
# Requirement already satisfied: fonttools>=4.22.0 in /Applications/anaconda3/envs/football-analysis/lib/python3.10/site-packages (from matplotlib->roboflow) (4.61.1)
# Requirement already satisfied: packaging>=20.0 in /Applications/anaconda3/envs/football-analysis/lib/python3.10/site-packages (from matplotlib->roboflow) (25.0)
# Requirement already satisfied: pyparsing>=3 in /Applications/anaconda3/envs/football-analysis/lib/python3.10/site-packages (from matplotlib->roboflow) (3.3.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Applications/anaconda3/envs/football-analysis/lib/python3.10/site-packages (from requests->roboflow) (3.4.4)
# Downloading roboflow-1.2.16-py3-none-any.whl (95 kB)
# Downloading idna-3.7-py3-none-any.whl (66 kB)
# Using cached opencv_python_headless-4.10.0.84-cp37-abi3-macosx_11_0_arm64.whl (54.8 MB)
# Downloading pi_heif-1.3.0-cp310-cp310-macosx_11_0_arm64.whl (942 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 942.3/942.3 kB 5.3 MB/s  0:00:00
# Downloading pillow_avif_plugin-1.5.5-cp310-cp310-macosx_11_0_arm64.whl (3.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 1.0 MB/s  0:00:030m eta 0:00:01
# Downloading tqdm-4.67.3-py3-none-any.whl (78 kB)
# Using cached filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Downloading python_dotenv-1.2.2-py3-none-any.whl (22 kB)
# Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Installing collected packages: pillow-avif-plugin, filetype, tqdm, python-dotenv, pi-heif, opencv-python-headless, idna, requests-toolbelt, roboflow
#   Attempting uninstall: idna━━╺━━━━━━━━━━━━━━━━━ 5/9 [opencv-python-headless]
#     Found existing installation: idna 3.1190m━━━━━━━━━━━━━━━━━ 5/9 [opencv-python-headless]
#     Uninstalling idna-3.11:╺━━━━━━━━━━━━━━━━━ 5/9 [opencv-python-headless]
#       Successfully uninstalled idna-3.11━━━━━━━━━━━━━━━━━ 5/9 [opencv-python-headless]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9/9 [roboflow] [opencv-python-headless]
# Successfully installed filetype-1.2.0 idna-3.7 opencv-python-headless-4.10.0.84 pi-heif-1.3.0 pillow-avif-plugin-1.5.5 python-dotenv-1.2.2 requests-toolbelt-1.0.0 roboflow-1.2.16 tqdm-4.67.3

# %% [markdown]
# # Get Datset

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="W36IbEJUIWaop0zESVXx")
project = rf.workspace("roboflow-jvuqo").project("football-players-detection-3zvbc")
version = project.version(1)
dataset = version.download("yolov5")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in football-players-detection-1 to yolov5pytorch:: 100%|██████████| 148663/148663 [00:18<00:00, 7863.59it/s]
# Extracting Dataset Version Zip to football-players-detection-1 in yolov5pytorch:: 100%|██████████| 1338/1338 [00:00<00:00, 2047.44it/s]

# %%
import shutil

shutil.move('football-players-detection-1/train',
            'football-players-detection-1/football-players-detection-1/train'
            )

shutil.move('football-players-detection-1/test',
            'football-players-detection-1/football-players-detection-1/test'
            )

shutil.move('football-players-detection-1/valid',
            'football-players-detection-1/football-players-detection-1/valid'
            )
# Out:
# 'football-players-detection-1/football-players-detection-1/valid'

# %% [markdown]
# # Training

# %%
# !yolo task=detect mode=train model=yolov5x.pt data={dataset.location}/data.yaml epochs=100 imgsz=640
